# %%
import scipy, scipy.signal, scipy.io.wavfile

def WavToOverlappedArray(filename="", window_size=1500, overlap = 500):
    fs, wave = scipy.io.wavfile.read(filename) 
    print(len(wave))
    print((wave))
    
    kimenet = []
    i = 0
    while i+1*window_size-overlap < len(wave):
        kimenet.append(   wave[(i*window_size-overlap)  :  (i+1*window_size-overlap)]   )
        print(wave[i*window_size-overlap  :  i+1*window_size-overlap])
        print(str(i+1*window_size-overlap) + " : " + str(i+2*window_size-overlap))
        i = i+overlap
    
    print("ennyi: "  + str(len(kimenet)))
    #print("ennyi: "  + str(kimenet))
    
    #windows_count = int(len(wave)/window_size)

    #kimenet = []
    #for i in range(windows_count):
    #  buffer = []
    #  for x in range(window_size):
    #    buffer.append(wave[i*window_size+x])
    #  kimenet.append(buffer)
    return 0

# %%
WavToOverlappedArray("sounds/alapjarat_mono.wav",15000, 500)
# Out:
# 6664964
# [-3612 -3445 -2579 ... -1599 -1591 -1179]
# []
# 14500 : 29500
# []
# 15000 : 30000
# []
# 15500 : 30500
# []
# 16000 : 31000
# []
# 16500 : 31500
# []
# 17000 : 32000
# []
# 17500 : 32500
# []
# 18000 : 33000
# []
# 18500 : 33500
# []
# 19000 : 34000
# []
# 19500 : 34500
# []
# 20000 : 35000
# []
# 20500 : 35500
# []
# 21000 : 36000
# []
# 21500 : 36500
# []
# 22000 : 37000
# []
# 22500 : 37500
# []
# 23000 : 38000
# []
# 23500 : 38500
# []
# 24000 : 39000
# []
# 24500 : 39500
# []
# 25000 : 40000
# []
# 25500 : 40500
# []
# 26000 : 41000
# []
# 26500 : 41500
# []
# 27000 : 42000
# []
# 27500 : 42500
# []
# 28000 : 43000
# []
# 28500 : 43500
# []
# 29000 : 44000
# []
# 29500 : 44500
# []
# 30000 : 45000
# []
# 30500 : 45500
# []
# 31000 : 46000
# []
# 31500 : 46500
# []
# 32000 : 47000
# []
# 32500 : 47500
# []
# 33000 : 48000
# []
# 33500 : 48500
# []
# 34000 : 49000
# []
# 34500 : 49500
# []
# 35000 : 50000
# []
# 35500 : 50500
# []
# 36000 : 51000
# []
# 36500 : 51500
# ...
