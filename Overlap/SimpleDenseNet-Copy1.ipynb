# %%
import random
import numpy as np
import scipy.io.wavfile
import scipy.signal
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta, Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy #TODO what to import here?
from tensorflow.keras.regularizers import l1
from tensorflow.keras.backend import clear_session
import tensorflow as tf
from tensorflow.keras.layers import Dropout


class DataKeeper:
    def __init__(self):
        self.RawDatas = []
        self.RawLabel = []
    def AddNewType(self, data, label):
        self.RawDatas.append(data)
        self.RawLabel.append(label)
    
    @property
    def KeptTypeCount(self):
        return len(self.RawDatas)
    
    def GetData(self, index):
        return self.RawDatas[index]
    
    def GenerateTrainTestValid(self, alpha=0.8):
        #if aplha is 0.8 -> train is 80%, valid is 10%, test is 10%
        SumRawDatas = []
        #létrehozzuk a teljes adatállományt egy tömbben
        for x in range(0, len(self.RawDatas)):
            for element in self.RawDatas[x]:
                SumRawDatas.append([element,self.RawLabel[x]])
        #összekeverjük
        random.shuffle(SumRawDatas)
        #szétválogatjuk 3 részre
        train = SumRawDatas[:int(len(SumRawDatas)*alpha)]
        test_valid = SumRawDatas[int(len(SumRawDatas)*alpha):]
        test = test_valid[:int(len(test_valid)*0.5)]
        valid = test_valid[int(len(test_valid)*0.5):]
        
        #x_train, y_train létrehozása
        self.x_train = []
        self.y_train = []
        for x in train:
            self.x_train.append(x[0])
            self.y_train.append(x[1])
            
        #x_test, y_test létrehozása
        self.x_test = []
        self.y_test = []
        for x in test:
            self.x_test.append(x[0])
            self.y_test.append(x[1])
            
        #x_valid, y_valid létrehozása
        self.x_valid = []
        self.y_valid = []
        for x in train:
            self.x_valid.append(x[0])
            self.y_valid.append(x[1])
            
        #numpy tömbbe konvertálás
        self.x_train = np.array(self.x_train)
        self.y_train = np.array(self.y_train)
        
        self.x_test = np.array(self.x_test)
        self.y_test = np.array(self.y_test)
        
        self.x_valid = np.array(self.x_valid)
        self.y_valid = np.array(self.y_valid) 
        print("Kész")

# %%
def WavToSplittedArray(filename="", window_size = 100):
    fs, wave = scipy.io.wavfile.read(filename) 
    windows_count = int(len(wave)/window_size)

    kimenet = []
    for i in range(windows_count):
      buffer = []
      for x in range(window_size):
        buffer.append(wave[i*window_size+x])
      kimenet.append(buffer)
    return kimenet

# %%
ablakmeret = 1500

Adatgyujto = DataKeeper()

Adatgyujto.AddNewType(WavToSplittedArray("sounds/1lehuzva_mono.wav", ablakmeret), 0)
Adatgyujto.AddNewType(WavToSplittedArray("sounds/2lehuzva_mono.wav", ablakmeret), 1)
Adatgyujto.AddNewType(WavToSplittedArray("sounds/alapjarat_mono.wav", ablakmeret),2)

# %%
Adatgyujto.GenerateTrainTestValid()
# Out:
# Kész

# %%
hidden_layer_1_size = 50
hidden_layer_2_size = 30


tf.compat.v1.reset_default_graph() # It's good practice to clea and reset everything
clear_session            # even using Keras


# Model
#######

x = Input(shape=(ablakmeret,))

# Hidden layers

d0_layer = Dropout(.3)(x)

hidden_layer_1 = Dense(units=hidden_layer_1_size, activation="relu", kernel_regularizer="l2")(d0_layer)

d1_layer = Dropout(.2)(hidden_layer_1)
    
hidden_layer_2 = Dense(units=hidden_layer_2_size, activation="relu", kernel_regularizer="l2")(d1_layer)

d2_layer = Dropout(.1)(hidden_layer_2)
                        

    
# Softmax 

predictions = Dense(Adatgyujto.KeptTypeCount, activation="softmax")(d2_layer) #TODO: What activation?

# Full model

model = Model(inputs=x, outputs=predictions)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1500)]            0
# _________________________________________________________________
# dropout (Dropout)            (None, 1500)              0
# _________________________________________________________________
# dense (Dense)                (None, 50)                75050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 76,673
# Trainable params: 76,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loss 

loss = sparse_categorical_crossentropy#TODO use the imported loss!

# Optimizer

optimizer = Adam() # A "smart" SGD variant 
 
# Compilation
#############

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"]) #TODO what to measure here?

history = model.fit(x=Adatgyujto.x_train, y=Adatgyujto.y_train,
                    validation_data=(Adatgyujto.x_valid, Adatgyujto.y_valid),
                    epochs=100,
                    batch_size=150)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 7ms/step - loss: 1763.3164 - accuracy: 0.5024 - val_loss: 486.7513 - val_accuracy: 0.6719
# Epoch 2/100
# 34/34 [==============================] - 0s 5ms/step - loss: 880.1967 - accuracy: 0.5783 - val_loss: 288.5404 - val_accuracy: 0.7078
# Epoch 3/100
# 34/34 [==============================] - 0s 5ms/step - loss: 580.7902 - accuracy: 0.6015 - val_loss: 174.0591 - val_accuracy: 0.7188
# Epoch 4/100
# 34/34 [==============================] - 0s 5ms/step - loss: 425.7411 - accuracy: 0.6151 - val_loss: 127.1469 - val_accuracy: 0.7176
# Epoch 5/100
# 34/34 [==============================] - 0s 6ms/step - loss: 307.7774 - accuracy: 0.6203 - val_loss: 81.7246 - val_accuracy: 0.7172
# Epoch 6/100
# 34/34 [==============================] - 0s 6ms/step - loss: 233.7268 - accuracy: 0.6169 - val_loss: 48.0105 - val_accuracy: 0.7016
# Epoch 7/100
# 34/34 [==============================] - 0s 6ms/step - loss: 177.3742 - accuracy: 0.5912 - val_loss: 27.2872 - val_accuracy: 0.6775
# Epoch 8/100
# 34/34 [==============================] - 0s 7ms/step - loss: 115.3670 - accuracy: 0.6050 - val_loss: 14.9933 - val_accuracy: 0.6449
# Epoch 9/100
# 34/34 [==============================] - 0s 6ms/step - loss: 78.7085 - accuracy: 0.5800 - val_loss: 8.3105 - val_accuracy: 0.5662
# Epoch 10/100
# 34/34 [==============================] - 0s 5ms/step - loss: 51.9911 - accuracy: 0.5537 - val_loss: 5.2107 - val_accuracy: 0.6087
# Epoch 11/100
# 34/34 [==============================] - 0s 5ms/step - loss: 44.1892 - accuracy: 0.5924 - val_loss: 3.5323 - val_accuracy: 0.6000
# Epoch 12/100
# 34/34 [==============================] - 0s 5ms/step - loss: 26.6505 - accuracy: 0.6279 - val_loss: 3.0990 - val_accuracy: 0.5480
# Epoch 13/100
# 34/34 [==============================] - 0s 5ms/step - loss: 22.3369 - accuracy: 0.6375 - val_loss: 2.7953 - val_accuracy: 0.6159
# Epoch 14/100
# 34/34 [==============================] - 0s 5ms/step - loss: 15.5906 - accuracy: 0.6224 - val_loss: 2.5388 - val_accuracy: 0.7050
# Epoch 15/100
# 34/34 [==============================] - 0s 5ms/step - loss: 16.3735 - accuracy: 0.6512 - val_loss: 2.3454 - val_accuracy: 0.6727
# Epoch 16/100
# 34/34 [==============================] - 0s 5ms/step - loss: 10.8943 - accuracy: 0.6423 - val_loss: 2.2625 - val_accuracy: 0.7068
# Epoch 17/100
100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3264 - accuracy: 0.7060 - val_loss: 2.1062 - val_accuracy: 0.7052
# Epoch 76/100
# 34/34 [==============================] - 0s 4ms/step - loss: 2.2813 - accuracy: 0.6920 - val_loss: 2.1073 - val_accuracy: 0.7052
# Epoch 77/100
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0299 - accuracy: 0.6992 - val_loss: 2.1080 - val_accuracy: 0.7070
# Epoch 78/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.5488 - accuracy: 0.6979 - val_loss: 2.1052 - val_accuracy: 0.7068
# Epoch 79/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3557 - accuracy: 0.7056 - val_loss: 2.1246 - val_accuracy: 0.7036
# Epoch 80/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3336 - accuracy: 0.6861 - val_loss: 2.1106 - val_accuracy: 0.7068
# Epoch 81/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3777 - accuracy: 0.6961 - val_loss: 2.0987 - val_accuracy: 0.7068
# Epoch 82/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.2436 - accuracy: 0.7007 - val_loss: 2.1006 - val_accuracy: 0.7046
# Epoch 83/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.2981 - accuracy: 0.6934 - val_loss: 2.1015 - val_accuracy: 0.7068
# Epoch 84/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3224 - accuracy: 0.6931 - val_loss: 2.1015 - val_accuracy: 0.7068
# Epoch 85/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.1748 - accuracy: 0.7015 - val_loss: 2.0990 - val_accuracy: 0.7068
# Epoch 86/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.5833 - accuracy: 0.6992 - val_loss: 2.1007 - val_accuracy: 0.7068
# Epoch 87/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.2764 - accuracy: 0.7007 - val_loss: 2.1027 - val_accuracy: 0.7044
# Epoch 88/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.3503 - accuracy: 0.6993 - val_loss: 2.0989 - val_accuracy: 0.7070
# Epoch 89/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.2030 - accuracy: 0.7046 - val_loss: 2.1018 - val_accuracy: 0.7068
# Epoch 90/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.2008 - accuracy: 0.7088 - val_loss: 2.1025 - val_accuracy: 0.7068
# Epoch 91/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.3932 - accuracy: 0.6973 - val_loss: 2.1076 - val_accuracy: 0.7048
# Epoch 92/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.5607 - accuracy: 0.6891 - val_loss: 2.0995 - val_accuracy: 0.7066
# Epoch 93/100
# 34/34 [==============================] - 0s 6ms/step - loss: 2.3866 - accuracy: 0.6963 - val_loss: 2.1050 - val_accuracy: 0.7006
# Epoch 94/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3529 - accuracy: 0.7023 - val_loss: 2.1015 - val_accuracy: 0.7056
# Epoch 95/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.2020 - accuracy: 0.7030 - val_loss: 2.0987 - val_accuracy: 0.7068
# Epoch 96/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.1781 - accuracy: 0.7074 - val_loss: 2.1045 - val_accuracy: 0.7068
# Epoch 97/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.1925 - accuracy: 0.7064 - val_loss: 2.0977 - val_accuracy: 0.7068
# Epoch 98/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.2597 - accuracy: 0.6949 - val_loss: 2.0988 - val_accuracy: 0.7068
# Epoch 99/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.1390 - accuracy: 0.6974 - val_loss: 2.0985 - val_accuracy: 0.7068
# Epoch 100/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2954 - accuracy: 0.7091 - val_loss: 2.0965 - val_accuracy: 0.7064

# %%
predikalando = 10

pred = model.predict(Adatgyujto.x_test[predikalando].reshape(1,ablakmeret))

print("ennek kene hogy legyen: " + str(Adatgyujto.y_test[predikalando]))
pred
# Out:
# ennek kene hogy legyen: 2
# array([[0.15911987, 0.1571548 , 0.6837253 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

def display_history(history):
    plt.plot(history.history['accuracy']) #TODO what to measure here for training?
    plt.plot(history.history['val_accuracy']) #TODO what to measure here for validation?
    plt.title('Model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    
display_history(history)

# %%
model.save("KerasModels/SimpleDenseNet.h5")
