# %%
import random
import numpy as np
import scipy.io.wavfile
import scipy.signal
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adadelta, Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy #TODO what to import here?
from tensorflow.keras.regularizers import l1
from tensorflow.keras.backend import clear_session
import tensorflow as tf
from tensorflow.keras.layers import Dropout


class DataKeeper:
    def __init__(self):
        self.RawDatas = []
        self.RawLabel = []
    def AddNewType(self, data, label):
        self.RawDatas.append(data)
        self.RawLabel.append(label)
    
    @property
    def KeptTypeCount(self):
        return len(self.RawDatas)
    
    def GetData(self, index):
        return self.RawDatas[index]
    
    def GenerateTrainTestValid(self, alpha=0.8):
        #if aplha is 0.8 -> train is 80%, valid is 10%, test is 10%
        SumRawDatas = []
        #létrehozzuk a teljes adatállományt egy tömbben
        for x in range(0, len(self.RawDatas)):
            for element in self.RawDatas[x]:
                SumRawDatas.append([element,self.RawLabel[x]])
        #összekeverjük
        random.shuffle(SumRawDatas)
        #szétválogatjuk 3 részre
        train = SumRawDatas[:int(len(SumRawDatas)*alpha)]
        test_valid = SumRawDatas[int(len(SumRawDatas)*alpha):]
        test = test_valid[:int(len(test_valid)*0.5)]
        valid = test_valid[int(len(test_valid)*0.5):]
        
        #x_train, y_train létrehozása
        self.x_train = []
        self.y_train = []
        for x in train:
            self.x_train.append(x[0])
            self.y_train.append(x[1])
            
        #x_test, y_test létrehozása
        self.x_test = []
        self.y_test = []
        for x in test:
            self.x_test.append(x[0])
            self.y_test.append(x[1])
            
        #x_valid, y_valid létrehozása
        self.x_valid = []
        self.y_valid = []
        for x in train:
            self.x_valid.append(x[0])
            self.y_valid.append(x[1])
            
        #numpy tömbbe konvertálás
        self.x_train = np.array(self.x_train)
        self.y_train = np.array(self.y_train)
        
        self.x_test = np.array(self.x_test)
        self.y_test = np.array(self.y_test)
        
        self.x_valid = np.array(self.x_valid)
        self.y_valid = np.array(self.y_valid) 
        print("Kész")

# %%
def WavToSplittedArray(filename="", window_size = 100):
    fs, wave = scipy.io.wavfile.read(filename) 
    windows_count = int(len(wave)/window_size)

    kimenet = []
    for i in range(windows_count):
      buffer = []
      for x in range(window_size):
        buffer.append(wave[i*window_size+x])
      kimenet.append(buffer)
    return kimenet

# %%
ablakmeret = 1500

Adatgyujto = DataKeeper()

Adatgyujto.AddNewType(WavToSplittedArray("sounds/1lehuzva_mono.wav", ablakmeret), 0)
Adatgyujto.AddNewType(WavToSplittedArray("sounds/2lehuzva_mono.wav", ablakmeret), 1)
Adatgyujto.AddNewType(WavToSplittedArray("sounds/alapjarat_mono.wav", ablakmeret),2)

# %%
Adatgyujto.GenerateTrainTestValid()
# Out:
# Kész

# %%
hidden_layer_1_size = 50
hidden_layer_2_size = 30


tf.compat.v1.reset_default_graph() # It's good practice to clea and reset everything
clear_session            # even using Keras


# Model
#######

x = Input(shape=(ablakmeret,))

# Hidden layers

d0_layer = Dropout(.3)(x)

hidden_layer_1 = Dense(units=hidden_layer_1_size, activation="relu", kernel_regularizer="l2")(d0_layer)

d1_layer = Dropout(.2)(hidden_layer_1)
    
hidden_layer_2 = Dense(units=hidden_layer_2_size, activation="relu", kernel_regularizer="l2")(d1_layer)

d2_layer = Dropout(.1)(hidden_layer_2)
                        

    
# Softmax 

predictions = Dense(Adatgyujto.KeptTypeCount, activation="softmax")(d2_layer) #TODO: What activation?

# Full model

model = Model(inputs=x, outputs=predictions)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 1500)]            0
# _________________________________________________________________
# dropout (Dropout)            (None, 1500)              0
# _________________________________________________________________
# dense (Dense)                (None, 50)                75050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 76,673
# Trainable params: 76,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loss 

loss = sparse_categorical_crossentropy#TODO use the imported loss!

# Optimizer

optimizer = Adam() # A "smart" SGD variant 
 
# Compilation
#############

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"]) #TODO what to measure here?

history = model.fit(x=Adatgyujto.x_train, y=Adatgyujto.y_train,
                    validation_data=(Adatgyujto.x_valid, Adatgyujto.y_valid),
                    epochs=100,
                    batch_size=150)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 11ms/step - loss: 1377.5988 - accuracy: 0.5409 - val_loss: 323.8133 - val_accuracy: 0.6467
# Epoch 2/100
# 34/34 [==============================] - 0s 7ms/step - loss: 632.4987 - accuracy: 0.5935 - val_loss: 169.2404 - val_accuracy: 0.6513
# Epoch 3/100
# 34/34 [==============================] - 0s 8ms/step - loss: 403.3149 - accuracy: 0.5906 - val_loss: 106.2507 - val_accuracy: 0.6657
# Epoch 4/100
# 34/34 [==============================] - 0s 8ms/step - loss: 267.9044 - accuracy: 0.5962 - val_loss: 57.4010 - val_accuracy: 0.6521
# Epoch 5/100
# 34/34 [==============================] - 0s 7ms/step - loss: 174.4607 - accuracy: 0.5888 - val_loss: 25.0194 - val_accuracy: 0.6167
# Epoch 6/100
# 34/34 [==============================] - 0s 11ms/step - loss: 111.2614 - accuracy: 0.5655 - val_loss: 9.6121 - val_accuracy: 0.4929
# Epoch 7/100
# 34/34 [==============================] - 0s 9ms/step - loss: 64.3472 - accuracy: 0.5745 - val_loss: 4.5695 - val_accuracy: 0.5057
# Epoch 8/100
# 34/34 [==============================] - 0s 9ms/step - loss: 42.6149 - accuracy: 0.5823 - val_loss: 3.5302 - val_accuracy: 0.3942
# Epoch 9/100
# 34/34 [==============================] - 0s 7ms/step - loss: 26.0985 - accuracy: 0.5682 - val_loss: 2.7901 - val_accuracy: 0.6783
# Epoch 10/100
# 34/34 [==============================] - 0s 7ms/step - loss: 25.7901 - accuracy: 0.5856 - val_loss: 2.4877 - val_accuracy: 0.6293
# Epoch 11/100
# 34/34 [==============================] - 0s 7ms/step - loss: 16.7509 - accuracy: 0.5892 - val_loss: 2.7451 - val_accuracy: 0.4727
# Epoch 12/100
# 34/34 [==============================] - 0s 7ms/step - loss: 16.6586 - accuracy: 0.5875 - val_loss: 2.4570 - val_accuracy: 0.6765
# Epoch 13/100
# 34/34 [==============================] - 0s 7ms/step - loss: 13.4961 - accuracy: 0.6124 - val_loss: 2.4504 - val_accuracy: 0.6169
# Epoch 14/100
# 34/34 [==============================] - 0s 7ms/step - loss: 10.0893 - accuracy: 0.6271 - val_loss: 2.3350 - val_accuracy: 0.6353
# Epoch 15/100
# 34/34 [==============================] - 0s 7ms/step - loss: 10.3368 - accuracy: 0.6122 - val_loss: 2.3095 - val_accuracy: 0.6349
# Epoch 16/100
# 34/34 [==============================] - 0s 7ms/step - loss: 10.9525 - accuracy: 0.6263 - val_loss: 2.4326 - val_accuracy: 0.5754
# Epoch 17/100
# 34/34 [==============================] - 0s 8ms/step - loss: 6.5650 - accuracy: 0.5988 - val_loss: 2.4371 - val_accuracy: 0.5187
# Epoch 18/100
# 34/34 [==============================] - 0s 7ms/step - loss: 8.3961 - accuracy: 0.6101 - val_loss: 2.6169 - val_accuracy: 0.3673
# Epoch 19/100
# 34/34 [==============================] - 0s 7ms/step - loss: 7.7193 - accuracy: 0.5915 - val_loss: 2.5686 - val_accuracy: 0.4396
# Epoch 20/100
# 34/34 [==============================] - 0s 9ms/step - loss: 5.0529 - accuracy: 0.6017 - val_loss: 2.4580 - val_accuracy: 0.4657
# Epoch 21/100
# 34/34 [==============================] - 0s 8ms/step - loss: 6.2576 - accuracy: 0.6315 - val_loss: 2.3053 - val_accuracy: 0.6231
# Epoch 22/100
# 34/34 [==============================] - 0s 7ms/step - loss: 4.8665 - accuracy: 0.6508 - val_loss: 2.4099 - val_accuracy: 0.5824
# Epoch 23/100
# 34/34 [==============================] - 0s 7ms/step - loss: 4.9156 - accuracy: 0.6436 - val_loss: 2.3091 - val_accuracy: 0.6373
# Epoch 24/100
# 34/34 [==============================] - 0s 7ms/step - loss: 6.0744 - accuracy: 0.6344 - val_loss: 2.3447 - val_accuracy: 0.7098
# Epoch 25/100
# 34/34 [==============================] - 0s 11ms/step - loss: 4.1024 - accuracy: 0.6528 - val_loss: 2.2598 - val_accuracy: 0.7094
# Epoch 26/100
# 34/34 [==============================] - 0s 10ms/step - loss: 4.2796 - accuracy: 0.6662 - val_loss: 2.2836 - val_accuracy: 0.6794
# Epoch 27/100
# 34/34 [==============================] - 0s 10ms/step - loss: 4.2918 - accuracy: 0.6337 - val_loss: 2.3985 - val_accuracy: 0.6199
# Epoch 28/100
# 34/34 [==============================] - 0s 11ms/step - loss: 4.1339 - accuracy: 0.6268 - val_loss: 2.2951 - val_accuracy: 0.6635
# Epoch 29/100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.7405 - accuracy: 0.6655 - val_loss: 2.2243 - val_accuracy: 0.7098
# Epoch 30/100
# 34/34 [==============================] - 0s 8ms/step - loss: 4.1516 - accuracy: 0.6874 - val_loss: 2.2462 - val_accuracy: 0.7098
# Epoch 31/100
# 34/34 [==============================] - 0s 7ms/step - loss: 4.4346 - accuracy: 0.6711 - val_loss: 2.3089 - val_accuracy: 0.6089
# Epoch 32/100
# 34/34 [==============================] - 0s 9ms/step - loss: 4.5459 - accuracy: 0.6513 - val_loss: 2.2436 - val_accuracy: 0.6824
# Epoch 33/100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.4254 - accuracy: 0.6660 - val_loss: 2.1913 - val_accuracy: 0.7084
# Epoch 34/100
# 34/34 [==============================] - 0s 8ms/step - loss: 3.1758 - accuracy: 0.6712 - val_loss: 2.2332 - val_accuracy: 0.6986
# Epoch 35/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.4557 - accuracy: 0.6632 - val_loss: 2.3137 - val_accuracy: 0.7090
# Epoch 36/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.9024 - accuracy: 0.6826 - val_loss: 2.2686 - val_accuracy: 0.6305
# Epoch 37/100
# 34/34 [==============================] - 0s 7ms/step - loss: 4.2224 - accuracy: 0.6696 - val_loss: 2.3301 - val_accuracy: 0.6217
# Epoch 38/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.9597 - accuracy: 0.6577 - val_loss: 2.2287 - val_accuracy: 0.6737
# Epoch 39/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.2158 - accuracy: 0.6648 - val_loss: 2.2033 - val_accuracy: 0.6962
# Epoch 40/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.2441 - accuracy: 0.6804 - val_loss: 2.2596 - val_accuracy: 0.6804
# Epoch 41/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.6573 - accuracy: 0.6607 - val_loss: 2.2241 - val_accuracy: 0.6503
# Epoch 42/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.7534 - accuracy: 0.6514 - val_loss: 2.1806 - val_accuracy: 0.7096
# Epoch 43/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.7514 - accuracy: 0.6897 - val_loss: 2.1995 - val_accuracy: 0.7098
# Epoch 44/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.9889 - accuracy: 0.6473 - val_loss: 2.2805 - val_accuracy: 0.6361
# Epoch 45/100
# 34/34 [==============================] - 0s 10ms/step - loss: 3.2366 - accuracy: 0.6664 - val_loss: 2.3105 - val_accuracy: 0.7096
# Epoch 46/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.7930 - accuracy: 0.6716 - val_loss: 2.1666 - val_accuracy: 0.7086
# Epoch 47/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.5179 - accuracy: 0.6675 - val_loss: 2.1933 - val_accuracy: 0.6810
# Epoch 48/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.5957 - accuracy: 0.6770 - val_loss: 2.2432 - val_accuracy: 0.6411
# Epoch 49/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.8387 - accuracy: 0.6672 - val_loss: 2.2462 - val_accuracy: 0.6347
# Epoch 50/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.7121 - accuracy: 0.6561 - val_loss: 2.1666 - val_accuracy: 0.7070
# Epoch 51/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.5391 - accuracy: 0.6913 - val_loss: 2.2427 - val_accuracy: 0.6631
# Epoch 52/100
# 34/34 [==============================] - 0s 7ms/step - loss: 3.3318 - accuracy: 0.6756 - val_loss: 2.1969 - val_accuracy: 0.6747
# Epoch 53/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.5408 - accuracy: 0.6761 - val_loss: 2.2263 - val_accuracy: 0.6531
# Epoch 54/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.9656 - accuracy: 0.6724 - val_loss: 2.1730 - val_accuracy: 0.7088
# Epoch 55/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.6925 - accuracy: 0.6708 - val_loss: 2.2225 - val_accuracy: 0.6507
# Epoch 56/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3117 - accuracy: 0.6788 - val_loss: 2.1654 - val_accuracy: 0.6982
# Epoch 57/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.3612 - accuracy: 0.6782 - val_loss: 2.1598 - val_accuracy: 0.7072
# Epoch 58/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.6151 - accuracy: 0.7046 - val_loss: 2.1796 - val_accuracy: 0.6830
# Epoch 59/100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.2430 - accuracy: 0.6869 - val_loss: 2.1523 - val_accuracy: 0.7078
# Epoch 60/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.7005 - accuracy: 0.6927 - val_loss: 2.1858 - val_accuracy: 0.6974
# Epoch 61/100
# 34/34 [==============================] - 0s 9ms/step - loss: 3.1937 - accuracy: 0.6861 - val_loss: 2.1812 - val_accuracy: 0.7040
# Epoch 62/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.6652 - accuracy: 0.6833 - val_loss: 2.1488 - val_accuracy: 0.7092
# Epoch 63/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.2736 - accuracy: 0.6925 - val_loss: 2.1517 - val_accuracy: 0.7098
# Epoch 64/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3655 - accuracy: 0.6903 - val_loss: 2.1569 - val_accuracy: 0.7062
# Epoch 65/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.5053 - accuracy: 0.6925 - val_loss: 2.1748 - val_accuracy: 0.6882
# Epoch 66/100
# 34/34 [==============================] - 0s 7ms/step - loss: 2.6728 - accuracy: 0.6945 - val_loss: 2.2420 - val_accuracy: 0.6397
# Epoch 67/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.5392 - accuracy: 0.6729 - val_loss: 2.1960 - val_accuracy: 0.6681
# Epoch 68/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.5953 - accuracy: 0.6798 - val_loss: 2.1916 - val_accuracy: 0.6681
# Epoch 69/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.7003 - accuracy: 0.6759 - val_loss: 2.1442 - val_accuracy: 0.7096
# Epoch 70/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.6482 - accuracy: 0.6864 - val_loss: 2.1435 - val_accuracy: 0.7098
# Epoch 71/100
# 34/34 [==============================] - 0s 13ms/step - loss: 2.4374 - accuracy: 0.7096 - val_loss: 2.1505 - val_accuracy: 0.7090
# Epoch 72/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.3338 - accuracy: 0.6957 - val_loss: 2.1734 - val_accuracy: 0.7098
# Epoch 73/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3465 - accuracy: 0.6952 - val_loss: 2.1397 - val_accuracy: 0.7092
# Epoch 74/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.4355 - accuracy: 0.6929 - val_loss: 2.1425 - val_accuracy: 0.7096
# Epoch 75/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.4220 - accuracy: 0.6996 - val_loss: 2.1418 - val_accuracy: 0.7098
# Epoch 76/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3175 - accuracy: 0.7000 - val_loss: 2.1459 - val_accuracy: 0.7026
# Epoch 77/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2295 - accuracy: 0.6982 - val_loss: 2.1712 - val_accuracy: 0.6838
# Epoch 78/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3110 - accuracy: 0.7036 - val_loss: 2.1371 - val_accuracy: 0.7098
# Epoch 79/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3221 - accuracy: 0.6857 - val_loss: 2.1393 - val_accuracy: 0.7098
# Epoch 80/100
# 34/34 [==============================] - 0s 12ms/step - loss: 2.1965 - accuracy: 0.7136 - val_loss: 2.1341 - val_accuracy: 0.7098
# Epoch 81/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.4527 - accuracy: 0.7110 - val_loss: 2.1401 - val_accuracy: 0.7062
# Epoch 82/100
# 34/34 [==============================] - 0s 12ms/step - loss: 2.1962 - accuracy: 0.7033 - val_loss: 2.1490 - val_accuracy: 0.7040
# Epoch 83/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.2341 - accuracy: 0.6973 - val_loss: 2.1308 - val_accuracy: 0.7096
# Epoch 84/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2202 - accuracy: 0.6953 - val_loss: 2.1355 - val_accuracy: 0.7098
# Epoch 85/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3196 - accuracy: 0.7099 - val_loss: 2.1409 - val_accuracy: 0.7040
# Epoch 86/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.2842 - accuracy: 0.7093 - val_loss: 2.1432 - val_accuracy: 0.7032
# Epoch 87/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2778 - accuracy: 0.7039 - val_loss: 2.1489 - val_accuracy: 0.6964
# Epoch 88/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2987 - accuracy: 0.7030 - val_loss: 2.1313 - val_accuracy: 0.7098
# Epoch 89/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2388 - accuracy: 0.7005 - val_loss: 2.1287 - val_accuracy: 0.7096
# Epoch 90/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.3806 - accuracy: 0.7122 - val_loss: 2.1366 - val_accuracy: 0.7076
# Epoch 91/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2522 - accuracy: 0.6971 - val_loss: 2.1331 - val_accuracy: 0.7098
# Epoch 92/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3106 - accuracy: 0.7117 - val_loss: 2.1339 - val_accuracy: 0.7068
# Epoch 93/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.5168 - accuracy: 0.7084 - val_loss: 2.1257 - val_accuracy: 0.7088
# Epoch 94/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.2849 - accuracy: 0.7028 - val_loss: 2.1281 - val_accuracy: 0.7098
# Epoch 95/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.2296 - accuracy: 0.6936 - val_loss: 2.1232 - val_accuracy: 0.7098
# Epoch 96/100
# 34/34 [==============================] - 0s 10ms/step - loss: 2.2353 - accuracy: 0.7068 - val_loss: 2.1298 - val_accuracy: 0.7050
# Epoch 97/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.4721 - accuracy: 0.6931 - val_loss: 2.1258 - val_accuracy: 0.7094
# Epoch 98/100
# 34/34 [==============================] - 0s 9ms/step - loss: 2.1911 - accuracy: 0.7003 - val_loss: 2.1216 - val_accuracy: 0.7096
# Epoch 99/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.1927 - accuracy: 0.6925 - val_loss: 2.1197 - val_accuracy: 0.7098
# Epoch 100/100
# 34/34 [==============================] - 0s 8ms/step - loss: 2.3616 - accuracy: 0.7048 - val_loss: 2.1217 - val_accuracy: 0.7098

# %%
predikalando = 10

pred = model.predict(Adatgyujto.x_test[predikalando].reshape(1,ablakmeret))

print("ennek kene hogy legyen: " + str(Adatgyujto.y_test[predikalando]))
pred
# Out:
# ennek kene hogy legyen: 2
# array([[0.15380281, 0.15367061, 0.6925265 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

def display_history(history):
    plt.plot(history.history['accuracy']) #TODO what to measure here for training?
    plt.plot(history.history['val_accuracy']) #TODO what to measure here for validation?
    plt.title('Model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    
display_history(history)

# %%
model.save("KerasModels/SimpleDenseNet.h5")
